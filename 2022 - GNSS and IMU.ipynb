# %%
from glob import glob
import glob
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import plotly.express as px
import seaborn as sns
import collections

# %%
train=glob.glob('C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train/*')

# %%
train[0]
# Out:
# 'C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train\\2020-05-15-US-MTV-1'

# %%
train1=glob.glob(train[0] + '/*')

# %%
print (train1)
# Out:
# ['C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train\\2020-05-15-US-MTV-1\\GooglePixel4XL']

# %%
file=glob.glob(train1[0] + '/*')

# %%
print(file)
# Out:
# ['C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train\\2020-05-15-US-MTV-1\\GooglePixel4XL\\device_gnss.csv', 'C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train\\2020-05-15-US-MTV-1\\GooglePixel4XL\\device_imu.csv', 'C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train\\2020-05-15-US-MTV-1\\GooglePixel4XL\\ground_truth.csv', 'C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train\\2020-05-15-US-MTV-1\\GooglePixel4XL\\supplemental']

# %%
device_gnss=glob.glob(train1[0] + 'device_gnss')

# %%
device_imu=glob.glob(train1[0] + 'device_imu')

# %%
for k in file:
    print(k)
# Out:
# C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train\2020-05-15-US-MTV-1\GooglePixel4XL\device_gnss.csv
# C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train\2020-05-15-US-MTV-1\GooglePixel4XL\device_imu.csv
# C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train\2020-05-15-US-MTV-1\GooglePixel4XL\ground_truth.csv
# C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train\2020-05-15-US-MTV-1\GooglePixel4XL\supplemental

# %%
train=glob.glob('C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train/*')
device_gnss = pd.DataFrame()


#collection_name=[]
#device_name=[]

for h in tqdm(train):
    train_ = glob.glob(h + '\\*')
    #col = h.split('/')[5]
    for i in train_:
        collection=i.split('/')[6].split('\\')
        

        device_gnss_ = glob.glob(i + '\\device_gnss.csv')
        device_imu_ = glob.glob(i +'\\device_imu.csv')
        device_gnss_df = pd.read_csv(device_gnss_[0])
        device_imu_df =pd.read_csv(device_imu_[0])
        common_pts=len(set(device_gnss_df['utcTimeMillis']).intersection(set(device_imu_df['utcTimeMillis'])))
        common=set(device_gnss_df['utcTimeMillis']).intersection(set(device_imu_df['utcTimeMillis']))

        gnss_pts=len(set(device_gnss_df['utcTimeMillis']))
        imu_pts=len(set(device_imu_df['utcTimeMillis']))
        print('Collection', collection[1], 'device', collection[2])
        print('GNSS',gnss_pts,'IMU' ,imu_pts,'Common' ,common_pts)
        print('--------------------------------------------------------')
        
        #common_gnss=device_gnss_df[device_gnss_df['utcTimeMillis'].isin(common)]
        #common_imu=
        
        #common_merge= pd.merge(common_gnss, common_imu, on='utc')
        #device_gnss_df['collection_name'] = collection[1]
        #device_gnss_df['device_name'] = collection[2]
        #device_gnss=device_gnss.append(device_gnss_df).reset_index(drop=True)
# Out:
#  50%|██████████████████████████████████████████                                          | 1/2 [00:05<00:05,  5.71s/it]
# Collection 2020-05-15-US-MTV-1 device GooglePixel4XL
# GNSS 3362 IMU 688437 Common 656
# --------------------------------------------------------
# Collection 2020-05-21-US-MTV-1 device GooglePixel4
# GNSS 1952 IMU 392463 Common 536
# --------------------------------------------------------
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:12<00:00,  6.04s/it]
# Collection 2020-05-21-US-MTV-1 device GooglePixel4XL
# GNSS 1947 IMU 391346 Common 431
# --------------------------------------------------------

# %%
# Out:
# 656

# %%
# Out:
# 688437

# %%
# Out:
# 3362

# %%
collection=i.split('/')[6].split('\\')

# %%
device_gnss_df
# Out:
#       MessageType  utcTimeMillis      TimeNanos  LeapSecond  \
# 0             Raw  1590084561437   363172000000         NaN
# 1             Raw  1590084561437   363172000000         NaN
# 2             Raw  1590084561437   363172000000         NaN
# 3             Raw  1590084561437   363172000000         NaN
# 4             Raw  1590084561437   363172000000         NaN
# ...           ...            ...            ...         ...
# 64492         Raw  1590086507437  2309172000000         NaN
# 64493         Raw  1590086507437  2309172000000         NaN
# 64494         Raw  1590086507437  2309172000000         NaN
# 64495         Raw  1590086507437  2309172000000         NaN
# 64496         Raw  1590086507437  2309172000000         NaN
#
#              FullBiasNanos  BiasNanos  BiasUncertaintyNanos  \
# 0     -1274119416265432668  -0.268681             20.504100
# 1     -1274119416265432668  -0.268681             20.504100
# 2     -1274119416265432668  -0.268681             20.504100
# 3     -1274119416265432668  -0.268681             20.504100
# 4     -1274119416265432668  -0.268681             20.504100
# ...                    ...        ...                   ...
# 64492 -1274119416265389252  -0.066612             22.241264
# 64493 -1274119416265389252  -0.066612             22.241264
# 64494 -1274119416265389252  -0.066612             22.241264
# 64495 -1274119416265389252  -0.066612             22.241264
# 64496 -1274119416265389252  -0.066612             22.241264
#
#        DriftNanosPerSecond  DriftUncertaintyNanosPerSecond  \
# 0                74.140837                       10.399463
# 1                74.140837                       10.399463
# 2                74.140837                       10.399463
# 3                74.140837                       10.399463
# 4                74.140837                       10.399463
# ...                    ...                             ...
# 64492           -17.713662                       11.668336
# 64493           -17.713662                       11.668336
# 64494           -17.713662                       11.668336
# 64495           -17.713662                       11.668336
# 64496           -17.713662                       11.668336
#
#        HardwareClockDiscontinuityCount  ...  SvVelocityYEcefMetersPerSecond  \
# 0                                    1  ...                     2747.386499
# 1                                    1  ...                     -370.248381
# 2                                    1  ...                     -679.448675
# 3                                    1  ...                     1003.495353
# 4                                    1  ...                      666.893816
# ...                                ...  ...                             ...
# 64492                                1  ...                      769.109168
# 64493                                1  ...                     -558.549667
# 64494                                1  ...                      169.440757
# 64495                                1  ...                    -2015.734504
# 64496                                1  ...                    -1800.750048
#
#        SvVelocityZEcefMetersPerSecond  SvClockBiasMeters  \
# 0                          755.471304      -1.149315e+05
# 1                        -3168.542750       3.543654e+03
# 2                        -2832.666801      -6.885670e+04
# 3                         1813.554794       8.044627e+04
# 4                         2693.434014      -4.668588e+04
# ...                               ...                ...
# 64492                    -2988.371114      -6.745860e+04
# 64493                    -2966.991641       4.045069e+04
# 64494                     3068.692172       2.596999e+05
# 64495                      729.264511       6.452074e+04
# 64496                    -1612.893776       1.165949e+06
#
#        SvClockDriftMetersPerSecond   IsrbMeters  IonosphericDelayMeters  \
# 0                        -0.002483     0.000000                6.411158
# 1                         0.001073     0.000000                4.169741
# 2                         0.001124     0.000000                4.747177
# 3                         0.002934     0.000000                2.756492
# 4                         0.001045     0.000000                2.789176
# ...                            ...          ...                     ...
# 64492                    -0.002918 -2349.424681               13.523159
# 64493                     0.000795 -2344.737164               11.617558
# 64494                    -0.000428 -2344.737164                7.174253
# 64495                    -0.002424 -2344.737164                6.811561
# 64496                    -0.009139 -2344.737164                5.522957
#
#        TroposphericDelayMeters  WlsPositionXEcefMeters  \
# 0                    10.981575           -2.694369e+06
# 1                     4.100631           -2.694369e+06
# 2                     5.239419           -2.694369e+06
# 3                     2.563702           -2.694369e+06
# 4                     2.588935           -2.694369e+06
# ...                        ...                     ...
# 64492                 8.878182           -2.712033e+06
# 64493                 6.868628           -2.712033e+06
# 64494                 3.509440           -2.712033e+06
# 64495                 3.608191           -2.712033e+06
# 64496                 2.740558           -2.712033e+06
#
#        WlsPositionYEcefMeters  WlsPositionZEcefMeters
# 0               -4.296550e+06            3.854882e+06
# 1               -4.296550e+06            3.854882e+06
# 2               -4.296550e+06            3.854882e+06
# 3               -4.296550e+06            3.854882e+06
# 4               -4.296550e+06            3.854882e+06
# ...                       ...                     ...
# 64492           -4.269231e+06            3.872742e+06
# 64493           -4.269231e+06            3.872742e+06
# 64494           -4.269231e+06            3.872742e+06
# 64495           -4.269231e+06            3.872742e+06
# 64496           -4.269231e+06            3.872742e+06
#
# [64497 rows x 47 columns]

# %%
collection
# Out:
# ['train', '2020-05-21-US-MTV-1', 'GooglePixel4XL']

# %%
device_gnss_df.tail()
# Out:
#       MessageType  utcTimeMillis      TimeNanos  LeapSecond  \
# 64492         Raw  1590086507437  2309172000000         NaN
# 64493         Raw  1590086507437  2309172000000         NaN
# 64494         Raw  1590086507437  2309172000000         NaN
# 64495         Raw  1590086507437  2309172000000         NaN
# 64496         Raw  1590086507437  2309172000000         NaN
#
#              FullBiasNanos  BiasNanos  BiasUncertaintyNanos  \
# 64492 -1274119416265389252  -0.066612             22.241264
# 64493 -1274119416265389252  -0.066612             22.241264
# 64494 -1274119416265389252  -0.066612             22.241264
# 64495 -1274119416265389252  -0.066612             22.241264
# 64496 -1274119416265389252  -0.066612             22.241264
#
#        DriftNanosPerSecond  DriftUncertaintyNanosPerSecond  \
# 64492           -17.713662                       11.668336
# 64493           -17.713662                       11.668336
# 64494           -17.713662                       11.668336
# 64495           -17.713662                       11.668336
# 64496           -17.713662                       11.668336
#
#        HardwareClockDiscontinuityCount  ...  SvVelocityYEcefMetersPerSecond  \
# 64492                                1  ...                      769.109168
# 64493                                1  ...                     -558.549667
# 64494                                1  ...                      169.440757
# 64495                                1  ...                    -2015.734504
# 64496                                1  ...                    -1800.750048
#
#        SvVelocityZEcefMetersPerSecond  SvClockBiasMeters  \
# 64492                    -2988.371114      -6.745860e+04
# 64493                    -2966.991641       4.045069e+04
# 64494                     3068.692172       2.596999e+05
# 64495                      729.264511       6.452074e+04
# 64496                    -1612.893776       1.165949e+06
#
#        SvClockDriftMetersPerSecond   IsrbMeters  IonosphericDelayMeters  \
# 64492                    -0.002918 -2349.424681               13.523159
# 64493                     0.000795 -2344.737164               11.617558
# 64494                    -0.000428 -2344.737164                7.174253
# 64495                    -0.002424 -2344.737164                6.811561
# 64496                    -0.009139 -2344.737164                5.522957
#
#        TroposphericDelayMeters  WlsPositionXEcefMeters  \
# 64492                 8.878182           -2.712033e+06
# 64493                 6.868628           -2.712033e+06
# 64494                 3.509440           -2.712033e+06
# 64495                 3.608191           -2.712033e+06
# 64496                 2.740558           -2.712033e+06
#
#        WlsPositionYEcefMeters  WlsPositionZEcefMeters
# 64492           -4.269231e+06            3.872742e+06
# 64493           -4.269231e+06            3.872742e+06
# 64494           -4.269231e+06            3.872742e+06
# 64495           -4.269231e+06            3.872742e+06
# 64496           -4.269231e+06            3.872742e+06
#
# [5 rows x 47 columns]

# %%
device_gnss_df=pd.read_csv("C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train/2020-05-15-US-MTV-1/GooglePixel4XL/device_gnss.csv")

# %%
device_gnss_df.head()
# Out:
#   MessageType  utcTimeMillis      TimeNanos  LeapSecond        FullBiasNanos  \
# 0         Raw  1589573679445  9825908000000         NaN -1273599071537525599
# 1         Raw  1589573679445  9825908000000         NaN -1273599071537525599
# 2         Raw  1589573679445  9825908000000         NaN -1273599071537525599
# 3         Raw  1589573679445  9825908000000         NaN -1273599071537525599
# 4         Raw  1589573679445  9825908000000         NaN -1273599071537525599
#
#    BiasNanos  BiasUncertaintyNanos  DriftNanosPerSecond  \
# 0   0.414394             29.760322             0.058358
# 1   0.414394             29.760322             0.058358
# 2   0.414394             29.760322             0.058358
# 3   0.414394             29.760322             0.058358
# 4   0.414394             29.760322             0.058358
#
#    DriftUncertaintyNanosPerSecond  HardwareClockDiscontinuityCount  ...  \
# 0                       10.712862                                6  ...
# 1                       10.712862                                6  ...
# 2                       10.712862                                6  ...
# 3                       10.712862                                6  ...
# 4                       10.712862                                6  ...
#
#    SvVelocityYEcefMetersPerSecond  SvVelocityZEcefMetersPerSecond  \
# 0                      -17.054923                     3156.993021
# 1                     1097.133346                     2801.579397
# 2                    -2177.983493                     1370.434597
# 3                      222.719634                     -841.694753
# 4                      293.424387                      302.063410
#
#    SvClockBiasMeters  SvClockDriftMetersPerSecond  IsrbMeters  \
# 0     -136834.550923                    -0.001592         0.0
# 1      -81575.252587                    -0.002044         0.0
# 2       35245.121840                    -0.002146         0.0
# 3       79527.095297                     0.003038         0.0
# 4      -47469.325722                     0.000590         0.0
#
#    IonosphericDelayMeters  TroposphericDelayMeters  WlsPositionXEcefMeters  \
# 0                4.733301                 3.394811           -2.693907e+06
# 1                3.933861                 2.831474           -2.693907e+06
# 2                5.685666                 4.716946           -2.693907e+06
# 3                5.565332                 4.452569           -2.693907e+06
# 4                4.065440                 3.035621           -2.693907e+06
#
#    WlsPositionYEcefMeters  WlsPositionZEcefMeters
# 0           -4.297452e+06            3.854203e+06
# 1           -4.297452e+06            3.854203e+06
# 2           -4.297452e+06            3.854203e+06
# 3           -4.297452e+06            3.854203e+06
# 4           -4.297452e+06            3.854203e+06
#
# [5 rows x 47 columns]

# %%
device_gnss_df.describe
# Out:
# <bound method NDFrame.describe of       MessageType  utcTimeMillis       TimeNanos  LeapSecond  \
# 0             Raw  1589573679445   9825908000000         NaN
# 1             Raw  1589573679445   9825908000000         NaN
# 2             Raw  1589573679445   9825908000000         NaN
# 3             Raw  1589573679445   9825908000000         NaN
# 4             Raw  1589573679445   9825908000000         NaN
# ...           ...            ...             ...         ...
# 90148         Raw  1589577040445  13186908000000         NaN
# 90149         Raw  1589577040445  13186908000000         NaN
# 90150         Raw  1589577040445  13186908000000         NaN
# 90151         Raw  1589577040445  13186908000000         NaN
# 90152         Raw  1589577040445  13186908000000         NaN
#
#              FullBiasNanos  BiasNanos  BiasUncertaintyNanos  \
# 0     -1273599071537525599   0.414394             29.760322
# 1     -1273599071537525599   0.414394             29.760322
# 2     -1273599071537525599   0.414394             29.760322
# 3     -1273599071537525599   0.414394             29.760322
# 4     -1273599071537525599   0.414394             29.760322
# ...                    ...        ...                   ...
# 90148 -1273599071537517829   0.863317             18.450928
# 90149 -1273599071537517829   0.863317             18.450928
# 90150 -1273599071537517829   0.863317             18.450928
# 90151 -1273599071537517829   0.863317             18.450928
# 90152 -1273599071537517829   0.863317             18.450928
#
#        DriftNanosPerSecond  DriftUncertaintyNanosPerSecond  \
# 0                 0.058358                       10.712862
# 1                 0.058358                       10.712862
# 2                 0.058358                       10.712862
# 3                 0.058358                       10.712862
# 4                 0.058358                       10.712862
# ...                    ...                             ...
# 90148             6.537852                        9.715101
# 90149             6.537852                        9.715101
# 90150             6.537852                        9.715101
# 90151             6.537852                        9.715101
# 90152             6.537852                        9.715101
#
#        HardwareClockDiscontinuityCount  ...  SvVelocityYEcefMetersPerSecond  \
# 0                                    6  ...                      -17.054923
# 1                                    6  ...                     1097.133346
# 2                                    6  ...                    -2177.983493
# 3                                    6  ...                      222.719634
# 4                                    6  ...                      293.424387
# ...                                ...  ...                             ...
# 90148                                7  ...                    -2560.769345
# 90149                                7  ...                    -1332.986509
# 90150                                7  ...                     -228.160204
# 90151                                7  ...                    -2406.056160
# 90152                                7  ...                     1237.500857
#
#        SvVelocityZEcefMetersPerSecond  SvClockBiasMeters  \
# 0                         3156.993021      -1.368346e+05
# 1                         2801.579397      -8.157525e+04
# 2                         1370.434597       3.524512e+04
# 3                         -841.694753       7.952710e+04
# 4                          302.063410      -4.746933e+04
# ...                               ...                ...
# 90148                     1124.324963       1.300448e+03
# 90149                    -2573.160692       4.004744e+04
# 90150                     2948.268971       2.599032e+05
# 90151                     -687.027713       1.170587e+06
# 90152                      865.977576       1.678042e+05
#
#        SvClockDriftMetersPerSecond   IsrbMeters  IonosphericDelayMeters  \
# 0                        -0.001592     0.000000                4.733301
# 1                        -0.002044     0.000000                3.933861
# 2                        -0.002146     0.000000                5.685666
# 3                         0.003038     0.000000                5.565332
# 4                         0.000590     0.000000                4.065440
# ...                            ...          ...                     ...
# 90148                     0.000022 -2351.409293               12.279992
# 90149                     0.000788 -2348.542977                6.990076
# 90150                    -0.000428 -2348.542977               16.376517
# 90151                    -0.009129 -2348.542977                7.696385
# 90152                    -0.001501 -2348.542977                7.721763
#
#        TroposphericDelayMeters  WlsPositionXEcefMeters  \
# 0                     3.394811           -2.693907e+06
# 1                     2.831474           -2.693907e+06
# 2                     4.716946           -2.693907e+06
# 3                     4.452569           -2.693907e+06
# 4                     3.035621           -2.693907e+06
# ...                        ...                     ...
# 90148                 5.939868           -2.711797e+06
# 90149                 2.671303           -2.711797e+06
# 90150                 8.686505           -2.711797e+06
# 90151                 3.070332           -2.711797e+06
# 90152                 3.077711           -2.711797e+06
#
#        WlsPositionYEcefMeters  WlsPositionZEcefMeters
# 0               -4.297452e+06            3.854203e+06
# 1               -4.297452e+06            3.854203e+06
# 2               -4.297452e+06            3.854203e+06
# 3               -4.297452e+06            3.854203e+06
# 4               -4.297452e+06            3.854203e+06
# ...                       ...                     ...
# 90148           -4.268995e+06            3.873143e+06
# 90149           -4.268995e+06            3.873143e+06
# 90150           -4.268995e+06            3.873143e+06
# 90151           -4.268995e+06            3.873143e+06
# 90152           -4.268995e+06            3.873143e+06
#
# [90153 rows x 47 columns]>

# %%
device_imu = pd.DataFrame()


#collection_name=[]
#device_name=[]

for h in tqdm(train):
    train = glob.glob(h + '/*')
    #col = h.split('/')[5]
    for i in train:
        collection= i.split('/')
        
        
        #device_imu
        device_imu = glob.glob(i + '/device_imu.csv')
        device_imu_df = pd.read_csv(device_imu[0])
        device_imu_df['collection_name'] = collection[4]
        device_imu_df['device_name'] = collection[3]
        device_imu=device_imu.append(device_imu_df).reset_index(drop=True)
# Out:
#   0%|                                                                                           | 0/62 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1088/778203055.py in <module>
#      17         device_imu_df['collection_name'] = collection[4]
#      18         device_imu_df['device_name'] = collection[3]
# ---> 19         device_imu=device_imu.append(device_imu_df).reset_index(drop=True)
#      20
#      21
#
# AttributeError: 'NoneType' object has no attribute 'reset_index'

# %%
device_imu_df=pd.read_csv("C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train/2020-05-15-US-MTV-1/GooglePixel4XL/device_imu.csv")

# %%
device_imu_df.head()

# %%
device_imu_df.tail()

# %%
device_gnss_df.shape

# %%
device_imu_df.shape

# %%
device_gnss_df.count()

# %%
device_imu_df.count()

# %%
device_gnss_df.isna()

# %%
device_imu_df.isna()

# %%
device_gnss_df.utcTimeMillis.hist()
plt.show()

# %%
device_imu_df.utcTimeMillis.hist()
plt.show()

# %%
train=glob.glob('C:/Users/kvenkatesh3/Downloads/Kaggle DS/smartphone-decimeter-2022/train/*')
device_imu = pd.DataFrame()


#collection_name=[]
#device_name=[]

for h in tqdm(train):
    train_ = glob.glob(h + '\\*')
    #col = h.split('/')[5]
    for i in train_:
        collection=i.split('/')[6].split('\\')
        

        device_imu_ = glob.glob(i + '\\device_imu.csv')
        device_imu_df = pd.read_csv(device_imu_[0])
        device_imu_df['collection_name'] = collection[1]
        device_imu_df['device_name'] = collection[2]
        device_imu=device_imu.append(device_imu_df).reset_index(drop=True)
